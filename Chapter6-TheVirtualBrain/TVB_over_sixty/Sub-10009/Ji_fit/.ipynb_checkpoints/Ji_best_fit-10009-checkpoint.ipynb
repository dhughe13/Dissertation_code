# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import norm

# %%
emp_FC = np.loadtxt('/home/dhughe13/TVB_over_sixty/Sub-10009/fc_10009a.txt',delimiter=',')

# %%
Ji_04 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-0.4.npy')
Ji_05 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-0.5.npy')
Ji_06 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-0.6.npy')
Ji_07 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-0.7.npy')
Ji_08 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-0.8.npy')
Ji_09 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-0.9.npy')
Ji_10 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.0.npy')
Ji_11 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.1.npy')
Ji_12 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.2.npy')
Ji_13 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.3.npy')
Ji_14 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.4.npy')
Ji_15 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.5.npy')
Ji_16 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.6.npy')
Ji_17 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.7.npy')
Ji_18 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.8.npy')
Ji_19 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-1.9.npy')
Ji_20 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-2.0.npy')
Ji_21 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-2.1.npy')
Ji_22 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-2.2.npy')
Ji_23 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-2.3.npy')
Ji_24 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-2.4.npy')
Ji_25 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-2.5.npy')
Ji_26 = np.load('/home/dhughe13/TVB_over_sixty/Sub-10009/Ji_fit/Ji_search_full-2.6.npy')

# %%
Ji_04.shape
# Out:
# (120, 96)

# %%
def FC(Ji_num):
    Ji_FC = np.corrcoef(Ji_num.T)
    return Ji_FC

def Pearson(Ji_FC,emp_FC):
    emp_FCf = np.ndarray.flatten(emp_FC)
    Ji_FCf = np.ndarray.flatten(Ji_FC)
    R = np.corrcoef(Ji_FCf,emp_FCf)
    Pearson = R[0,1]
    return Pearson

# %%
Ji04_FC = FC(Ji_04)
Ji04_P = Pearson(Ji04_FC,emp_FC)

Ji05_FC = FC(Ji_05)
Ji05_P = Pearson(Ji05_FC,emp_FC)

Ji06_FC = FC(Ji_06)
Ji06_P = Pearson(Ji06_FC,emp_FC)

Ji07_FC = FC(Ji_07)
Ji07_P = Pearson(Ji07_FC,emp_FC)

Ji08_FC = FC(Ji_08)
Ji08_P = Pearson(Ji08_FC,emp_FC)

Ji09_FC = FC(Ji_09)
Ji09_P = Pearson(Ji09_FC,emp_FC)

Ji10_FC = FC(Ji_10)
Ji10_P = Pearson(Ji10_FC,emp_FC)

Ji11_FC = FC(Ji_11)
Ji11_P = Pearson(Ji11_FC,emp_FC)

Ji12_FC = FC(Ji_12)
Ji12_P = Pearson(Ji12_FC,emp_FC)

Ji13_FC = FC(Ji_13)
Ji13_P = Pearson(Ji13_FC,emp_FC)

Ji14_FC = FC(Ji_14)
Ji14_P = Pearson(Ji14_FC,emp_FC)

Ji15_FC = FC(Ji_15)
Ji15_P = Pearson(Ji15_FC,emp_FC)

Ji16_FC = FC(Ji_16)
Ji16_P = Pearson(Ji16_FC,emp_FC)

Ji17_FC = FC(Ji_17)
Ji17_P = Pearson(Ji17_FC,emp_FC)

Ji18_FC = FC(Ji_18)
Ji18_P = Pearson(Ji18_FC,emp_FC)

Ji19_FC = FC(Ji_19)
Ji19_P = Pearson(Ji19_FC,emp_FC)

Ji20_FC = FC(Ji_20)
Ji20_P = Pearson(Ji20_FC,emp_FC)

Ji21_FC = FC(Ji_21)
Ji21_P = Pearson(Ji21_FC,emp_FC)

Ji22_FC = FC(Ji_22)
Ji22_P = Pearson(Ji22_FC,emp_FC)

Ji23_FC = FC(Ji_23)
Ji23_P = Pearson(Ji23_FC,emp_FC)

Ji24_FC = FC(Ji_24)
Ji24_P = Pearson(Ji24_FC,emp_FC)

Ji25_FC = FC(Ji_25)
Ji25_P = Pearson(Ji25_FC,emp_FC)

Ji26_FC = FC(Ji_26)
Ji26_P = Pearson(Ji26_FC,emp_FC)

# %%
Ji = np.arange(0.4, 2.7, 0.1)
print(Ji.size)
Ji_P = [Ji04_P, Ji05_P, Ji06_P, Ji07_P, Ji08_P, Ji09_P,
        Ji10_P, Ji11_P, Ji12_P, Ji13_P, Ji14_P, Ji15_P, 
        Ji16_P, Ji17_P, Ji18_P, Ji19_P, Ji20_P, Ji21_P,
        Ji22_P, Ji23_P, Ji24_P, Ji25_P, Ji26_P]
np.save('Ji_P-10009.npy', Ji_P)
# Out:
# 23

# %%
fig, ax = plt.subplots(1,1, figsize=(10,5))
img = ax.plot(Ji,Ji_P)
# ax.set_xticks(np.arange(0,23,1))
# ax.set_xticklabels(Ji)
plt.xlabel('Ji values')
plt.ylabel('Pearson Values')
plt.title('Pearson Correlations, Ji-10009')
plt.savefig('P_bf_Ji-10009')

# %%
max = np.max(Ji_P)
max_index = np.argmax(Ji_P)
print(max)
print(max_index)
print(Ji[max_index])
# Out:
# 0.3739947375946325
# 7
# 1.0999999999999999
